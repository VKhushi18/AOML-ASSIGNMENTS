# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
train_df_dir = "train.csv"
test_df_dir = "test.csv"

# %%
train_df = pd.read_csv(train_df_dir)
test_df = pd.read_csv(test_df_dir)

# %%
test_uid = test_df["uid"]

train_df.drop("uid", axis=1, inplace=True)
test_df.drop("uid", axis=1, inplace=True)

day_map = {
    "Friday": 0,
    "Saturday": 1,
}

train_df["day"] = train_df["day"].map(day_map)
test_df["day"] = test_df["day"].map(day_map)

train_df.drop("minute", axis=1, inplace=True)
test_df.drop("minute", axis=1, inplace=True)

print(train_df.isna().sum())
# Out:
# day                              5479
# hour                             5613
# C_motion                         5517
# feed_water_motion                5597
# faucet_hole                      5566
# vapour_pressure                  5479
# vapour_enthalpy                  5437
# vapour_pressure_at_division      5477
# vapour_motion                    5477
# feed_water_enth                  5496
# vapour_temperature               5517
# output_electricity_generation       0
# dtype: int64

# %%
from sklearn.neighbors import KNeighborsRegressor


def KNN_Imputer(df):
    for i in df.columns:
        if df[i].isna().sum() == 0:
            continue

        temp_df = df.copy()
        for x in df.columns:
            if x == i:
                continue
            temp_df[x].fillna(value=temp_df[x].mean(), inplace=True)

        col = i
        other_cols = [x for x in df.columns if x != col]
        X = temp_df[other_cols][df[col].notna()]
        y = temp_df[col][df[col].notna()]

        neigh = KNeighborsRegressor(n_neighbors=3)
        neigh.fit(np.array(X), np.array(y))

        print(f"Imputing {i}")
        for i, j in enumerate(df[col].isnull()):
            if j == True:
                df[col].iloc[i] = neigh.predict(temp_df[other_cols].iloc[i : i + 1, :])[
                    0
                ]
    return df


train_df = KNN_Imputer(train_df)
test_df = KNN_Imputer(test_df)

print(train_df.isna().sum())
# Out:
# Imputing day
# Imputing hour
# Imputing C_motion
# Imputing feed_water_motion
# Imputing faucet_hole
# Imputing vapour_pressure
# Imputing vapour_enthalpy
# Imputing vapour_pressure_at_division
# Imputing vapour_motion
# Imputing feed_water_enth
# Imputing vapour_temperature
# Imputing day
# Imputing hour
# Imputing C_motion
# Imputing feed_water_motion
# Imputing faucet_hole
# Imputing vapour_pressure
# Imputing vapour_enthalpy
# Imputing vapour_pressure_at_division
# Imputing vapour_motion
# Imputing feed_water_enth
# Imputing vapour_temperature
# day                              0
# hour                             0
# C_motion                         0
# feed_water_motion                0
# faucet_hole                      0
# vapour_pressure                  0
# vapour_enthalpy                  0
# vapour_pressure_at_division      0
# vapour_motion                    0
# feed_water_enth                  0
# vapour_temperature               0
# output_electricity_generation    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = train_df.drop("output_electricity_generation", axis=1)
y = train_df["output_electricity_generation"]

X["vapour_pressure_per_temp"] = X["vapour_pressure"] / X["vapour_temperature"]
test_df["vapour_pressure_per_temp"] = (
    test_df["vapour_pressure"] / test_df["vapour_temperature"]
)

X["vapour_enthalpy_per_temp"] = X["vapour_enthalpy"] / X["vapour_temperature"]
test_df["vapour_enthalpy_per_temp"] = (
    test_df["vapour_enthalpy"] / test_df["vapour_temperature"]
)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train["hour_sin"] = np.sin(2 * np.pi * X_train["hour"] / 23.0)
X_train["hour_cos"] = np.cos(2 * np.pi * X_train["hour"] / 23.0)

X_test["hour_sin"] = np.sin(2 * np.pi * X_test["hour"] / 23.0)
X_test["hour_cos"] = np.cos(2 * np.pi * X_test["hour"] / 23.0)

test_df["hour_sin"] = np.sin(2 * np.pi * test_df["hour"] / 23.0)
test_df["hour_cos"] = np.cos(2 * np.pi * test_df["hour"] / 23.0)

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import mean_squared_error


def objective(trial):
    param = {
        "objective": "regression",
        "metric": "rmse",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }

    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

    model = lgb.train(param, lgb_train, valid_sets=[lgb_train, lgb_eval])

    y_pred = model.predict(X_test, num_iteration=model.best_iteration)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    return rmse


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)

lgb_params = study.best_params
lgb_params["objective"] = "regression"
lgb_params["metric"] = "rmse"
lgb_params["verbosity"] = -1
lgb_params["boosting_type"] = "gbdt"

lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

lgb_model = lgb.train(lgb_params, lgb_train, valid_sets=[lgb_train, lgb_eval])

lgb_pred = lgb_model.predict(X_test, num_iteration=lgb_model.best_iteration)
lgb_rmse = np.sqrt(mean_squared_error(y_test, lgb_pred))
print(f"LightGBM RMSE: {lgb_rmse}\n")
# Out:
# [I 2025-03-08 23:45:03,414] A new study created in memory with name: no-name-775bf1d2-04ac-468e-9d64-c29378f1c5a6
# [I 2025-03-08 23:45:04,224] Trial 0 finished with value: 1.0012692448386569 and parameters: {'lambda_l1': 5.789940319717543e-07, 'lambda_l2': 0.00014909020055718186, 'num_leaves': 233, 'feature_fraction': 0.7289139942704017, 'bagging_fraction': 0.42061577568864245, 'bagging_freq': 3, 'min_child_samples': 25}. Best is trial 0 with value: 1.0012692448386569.
# [I 2025-03-08 23:45:04,775] Trial 1 finished with value: 1.3001504646488515 and parameters: {'lambda_l1': 8.983293063948936e-07, 'lambda_l2': 2.9125163093981784e-07, 'num_leaves': 214, 'feature_fraction': 0.7798267379903163, 'bagging_fraction': 0.520701422195395, 'bagging_freq': 2, 'min_child_samples': 82}. Best is trial 0 with value: 1.0012692448386569.
# [I 2025-03-08 23:45:05,312] Trial 2 finished with value: 1.008626353504314 and parameters: {'lambda_l1': 3.513720643653179e-08, 'lambda_l2': 1.1661002814819067e-06, 'num_leaves': 138, 'feature_fraction': 0.8231705021723001, 'bagging_fraction': 0.9167878644412838, 'bagging_freq': 3, 'min_child_samples': 28}. Best is trial 0 with value: 1.0012692448386569.
# [I 2025-03-08 23:45:05,549] Trial 3 finished with value: 1.6076831945878465 and parameters: {'lambda_l1': 9.900825822965875e-05, 'lambda_l2': 6.66555119773194e-06, 'num_leaves': 31, 'feature_fraction': 0.9471307980468255, 'bagging_fraction': 0.9103439565813758, 'bagging_freq': 7, 'min_child_samples': 46}. Best is trial 0 with value: 1.0012692448386569.
# [I 2025-03-08 23:45:05,837] Trial 4 finished with value: 1.4091195614640828 and parameters: {'lambda_l1': 6.127919697562138, 'lambda_l2': 0.00015133669144338293, 'num_leaves': 50, 'feature_fraction': 0.5623738675165685, 'bagging_fraction': 0.9949670536660429, 'bagging_freq': 4, 'min_child_samples': 50}. Best is trial 0 with value: 1.0012692448386569.
# [I 2025-03-08 23:45:06,208] Trial 5 finished with value: 1.3214068688551204 and parameters: {'lambda_l1': 0.0020560929129759286, 'lambda_l2': 1.3611510502976931, 'num_leaves': 69, 'feature_fraction': 0.93449945309756, 'bagging_fraction': 0.42829029879689917, 'bagging_freq': 3, 'min_child_samples': 27}. Best is trial 0 with value: 1.0012692448386569.
# [I 2025-03-08 23:45:06,632] Trial 6 finished with value: 1.9507263492561506 and parameters: {'lambda_l1': 0.008365201230089103, 'lambda_l2': 2.4258827974792156, 'num_leaves': 239, 'feature_fraction': 0.529696778174265, 'bagging_fraction': 0.41497755251928037, 'bagging_freq': 3, 'min_child_samples': 85}. Best is trial 0 with value: 1.0012692448386569.
# [I 2025-03-08 23:45:07,285] Trial 7 finished with value: 0.9969180900131528 and parameters: {'lambda_l1': 3.279668721444269e-05, 'lambda_l2': 2.2671844396593964e-07, 'num_leaves': 224, 'feature_fraction': 0.8045025101776978, 'bagging_fraction': 0.7984002866800958, 'bagging_freq': 2, 'min_child_samples': 40}. Best is trial 7 with value: 0.9969180900131528.
# [I 2025-03-08 23:45:08,230] Trial 8 finished with value: 1.1285682847737868 and parameters: {'lambda_l1': 0.006510796885223468, 'lambda_l2': 0.0023837413158347355, 'num_leaves': 244, 'feature_fraction': 0.6664783681667314, 'bagging_fraction': 0.967388111207179, 'bagging_freq': 2, 'min_child_samples': 87}. Best is trial 7 with value: 0.9969180900131528.
# [I 2025-03-08 23:45:08,817] Trial 9 finished with value: 1.1249818229194557 and parameters: {'lambda_l1': 5.498498312641225e-05, 'lambda_l2': 0.004724119403582782, 'num_leaves': 191, 'feature_fraction': 0.6100018837924079, 'bagging_fraction': 0.853678934453221, 'bagging_freq': 1, 'min_child_samples': 38}. Best is trial 7 with value: 0.9969180900131528.
# [I 2025-03-08 23:45:09,324] Trial 10 finished with value: 1.0577155346369458 and parameters: {'lambda_l1': 0.38740927026027666, 'lambda_l2': 1.7749927307820465e-08, 'num_leaves': 156, 'feature_fraction': 0.4286341466213226, 'bagging_fraction': 0.7129957853812365, 'bagging_freq': 6, 'min_child_samples': 6}. Best is trial 7 with value: 0.9969180900131528.
# [I 2025-03-08 23:45:10,112] Trial 11 finished with value: 1.1392866024530388 and parameters: {'lambda_l1': 1.4771278881232244e-06, 'lambda_l2': 0.0001464189832296499, 'num_leaves': 186, 'feature_fraction': 0.77527722333693, 'bagging_fraction': 0.7155189971927843, 'bagging_freq': 5, 'min_child_samples': 66}. Best is trial 7 with value: 0.9969180900131528.
# [I 2025-03-08 23:45:10,539] Trial 12 finished with value: 1.0437112643680833 and parameters: {'lambda_l1': 1.6362785705517565e-06, 'lambda_l2': 7.617172094507459e-06, 'num_leaves': 110, 'feature_fraction': 0.8529223217026187, 'bagging_fraction': 0.5984529384175343, 'bagging_freq': 1, 'min_child_samples': 9}. Best is trial 7 with value: 0.9969180900131528.
# [I 2025-03-08 23:45:11,606] Trial 13 finished with value: 1.0687699458814401 and parameters: {'lambda_l1': 1.4618162072000518e-08, 'lambda_l2': 1.0421658631615595e-08, 'num_leaves': 250, 'feature_fraction': 0.7164302404308999, 'bagging_fraction': 0.7974297645201801, 'bagging_freq': 4, 'min_child_samples': 64}. Best is trial 7 with value: 0.9969180900131528.
# [I 2025-03-08 23:45:12,408] Trial 14 finished with value: 0.9834908255479868 and parameters: {'lambda_l1': 8.917358443177927e-06, 'lambda_l2': 0.08534292560463363, 'num_leaves': 197, 'feature_fraction': 0.6983899553853069, 'bagging_fraction': 0.6218189755625001, 'bagging_freq': 2, 'min_child_samples': 26}. Best is trial 14 with value: 0.9834908255479868.
# [I 2025-03-08 23:45:13,196] Trial 15 finished with value: 1.0294602068473113 and parameters: {'lambda_l1': 2.1198519494946995e-05, 'lambda_l2': 0.08194107582379442, 'num_leaves': 181, 'feature_fraction': 0.8735742061982059, 'bagging_fraction': 0.6390091655744656, 'bagging_freq': 2, 'min_child_samples': 39}. Best is trial 14 with value: 0.9834908255479868.
# [I 2025-03-08 23:45:13,818] Trial 16 finished with value: 0.935159853946654 and parameters: {'lambda_l1': 0.000943088017221643, 'lambda_l2': 0.09673862873649595, 'num_leaves': 207, 'feature_fraction': 0.6616038512135908, 'bagging_fraction': 0.7913082334109149, 'bagging_freq': 1, 'min_child_samples': 18}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:14,200] Trial 17 finished with value: 1.1106920685205237 and parameters: {'lambda_l1': 0.0007361775667291541, 'lambda_l2': 0.2111256787213598, 'num_leaves': 99, 'feature_fraction': 0.6395622816802962, 'bagging_fraction': 0.6081965829878954, 'bagging_freq': 1, 'min_child_samples': 19}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:14,680] Trial 18 finished with value: 1.0397357258398747 and parameters: {'lambda_l1': 0.13119388787811603, 'lambda_l2': 0.02910120465261339, 'num_leaves': 163, 'feature_fraction': 0.4813675517560493, 'bagging_fraction': 0.5363349478697047, 'bagging_freq': 1, 'min_child_samples': 15}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:15,233] Trial 19 finished with value: 1.3182608321132943 and parameters: {'lambda_l1': 0.044965741177662985, 'lambda_l2': 8.560963146137619, 'num_leaves': 201, 'feature_fraction': 0.5636342536082476, 'bagging_fraction': 0.7657389886145356, 'bagging_freq': 5, 'min_child_samples': 66}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:15,843] Trial 20 finished with value: 1.3308676860805133 and parameters: {'lambda_l1': 6.9758779590673135e-06, 'lambda_l2': 0.002878343428854023, 'num_leaves': 134, 'feature_fraction': 0.6943496628373932, 'bagging_fraction': 0.676205127621978, 'bagging_freq': 2, 'min_child_samples': 100}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:16,606] Trial 21 finished with value: 0.9792734826313008 and parameters: {'lambda_l1': 0.00032687099326305584, 'lambda_l2': 0.370262696946002, 'num_leaves': 213, 'feature_fraction': 0.7712497834755545, 'bagging_fraction': 0.7987452123383525, 'bagging_freq': 2, 'min_child_samples': 34}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:17,237] Trial 22 finished with value: 0.9853286293498849 and parameters: {'lambda_l1': 0.0002960042763733923, 'lambda_l2': 0.4087868441298162, 'num_leaves': 209, 'feature_fraction': 0.7523753902438673, 'bagging_fraction': 0.8596548809736586, 'bagging_freq': 1, 'min_child_samples': 32}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:17,813] Trial 23 finished with value: 1.0375004248241644 and parameters: {'lambda_l1': 0.000679010485140319, 'lambda_l2': 0.02642036687222716, 'num_leaves': 169, 'feature_fraction': 0.6296681344806687, 'bagging_fraction': 0.7479755507584311, 'bagging_freq': 2, 'min_child_samples': 18}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:18,478] Trial 24 finished with value: 0.9468701732320103 and parameters: {'lambda_l1': 8.391356689614799e-08, 'lambda_l2': 0.8530230315218369, 'num_leaves': 213, 'feature_fraction': 0.6806118561411174, 'bagging_fraction': 0.8454412593530511, 'bagging_freq': 3, 'min_child_samples': 13}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:18,919] Trial 25 finished with value: 1.1033488853303446 and parameters: {'lambda_l1': 1.3165190681846813e-07, 'lambda_l2': 7.445022642618414, 'num_leaves': 151, 'feature_fraction': 0.894564341580272, 'bagging_fraction': 0.8497300167858264, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:19,699] Trial 26 finished with value: 1.069250057614207 and parameters: {'lambda_l1': 0.016606218183135103, 'lambda_l2': 0.7515403959451339, 'num_leaves': 253, 'feature_fraction': 0.9914533983448417, 'bagging_fraction': 0.8114515329546924, 'bagging_freq': 4, 'min_child_samples': 21}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:20,410] Trial 27 finished with value: 1.0624715140438667 and parameters: {'lambda_l1': 0.00025130968269295763, 'lambda_l2': 0.01562623645855622, 'num_leaves': 221, 'feature_fraction': 0.6012768421799009, 'bagging_fraction': 0.9010540289790699, 'bagging_freq': 1, 'min_child_samples': 57}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:20,782] Trial 28 finished with value: 1.0671401829466445 and parameters: {'lambda_l1': 0.6003079222969905, 'lambda_l2': 0.23940081962212348, 'num_leaves': 114, 'feature_fraction': 0.6707559143040804, 'bagging_fraction': 0.7529040255934842, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:21,613] Trial 29 finished with value: 0.9562671901435947 and parameters: {'lambda_l1': 1.904088047466922e-07, 'lambda_l2': 0.0008830404796414622, 'num_leaves': 235, 'feature_fraction': 0.7512750100212893, 'bagging_fraction': 0.9466065335030798, 'bagging_freq': 3, 'min_child_samples': 33}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:22,392] Trial 30 finished with value: 0.9648642928513742 and parameters: {'lambda_l1': 1.8645691967062268e-07, 'lambda_l2': 0.0008392150749675666, 'num_leaves': 232, 'feature_fraction': 0.7519961428874845, 'bagging_fraction': 0.9505215818033322, 'bagging_freq': 4, 'min_child_samples': 22}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:23,246] Trial 31 finished with value: 0.982262262961779 and parameters: {'lambda_l1': 1.714766201038519e-07, 'lambda_l2': 0.0006666842544026709, 'num_leaves': 224, 'feature_fraction': 0.7371507267436691, 'bagging_fraction': 0.9399268324420659, 'bagging_freq': 4, 'min_child_samples': 21}. Best is trial 16 with value: 0.935159853946654.
# [I 2025-03-08 23:45:23,924] Trial 32 finished with value: 0.9090297446867125 and parameters: {'lambda_l1': 1.7013412695025772e-07, 'lambda_l2': 0.0005787505589470561, 'num_leaves': 256, 'feature_fraction': 0.7276193967017404, 'bagging_fraction': 0.8761936637093819, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:24,686] Trial 33 finished with value: 0.920935006241007 and parameters: {'lambda_l1': 5.852703580253017e-08, 'lambda_l2': 9.960632973412735e-05, 'num_leaves': 236, 'feature_fraction': 0.822119778153877, 'bagging_fraction': 0.8831691481846167, 'bagging_freq': 3, 'min_child_samples': 14}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:25,490] Trial 34 finished with value: 0.9145967691034022 and parameters: {'lambda_l1': 1.055686720686786e-08, 'lambda_l2': 3.528788965181719e-05, 'num_leaves': 256, 'feature_fraction': 0.8015285130608619, 'bagging_fraction': 0.8817106096539346, 'bagging_freq': 3, 'min_child_samples': 13}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:26,293] Trial 35 finished with value: 0.9989483151703527 and parameters: {'lambda_l1': 1.1452072911654464e-08, 'lambda_l2': 2.5631047355014816e-05, 'num_leaves': 255, 'feature_fraction': 0.9036938057239824, 'bagging_fraction': 0.8789738996078307, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:26,968] Trial 36 finished with value: 0.9211165864120723 and parameters: {'lambda_l1': 3.205698543914439e-08, 'lambda_l2': 4.490640970346412e-05, 'num_leaves': 256, 'feature_fraction': 0.8237220640555583, 'bagging_fraction': 0.996533085132091, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:27,722] Trial 37 finished with value: 0.9396684764474849 and parameters: {'lambda_l1': 3.9065544646115284e-08, 'lambda_l2': 9.546393778342415e-05, 'num_leaves': 236, 'feature_fraction': 0.8036973962970708, 'bagging_fraction': 0.9904956014297345, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:27,836] Trial 38 finished with value: 3.1818439152430957 and parameters: {'lambda_l1': 5.659294329222957e-07, 'lambda_l2': 2.1446718508440026e-05, 'num_leaves': 6, 'feature_fraction': 0.8413610238284188, 'bagging_fraction': 0.8893469387643194, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:28,718] Trial 39 finished with value: 0.9990196046216295 and parameters: {'lambda_l1': 6.556711011384075e-07, 'lambda_l2': 8.18796510520333e-07, 'num_leaves': 256, 'feature_fraction': 0.821132369739805, 'bagging_fraction': 0.9195200192150191, 'bagging_freq': 6, 'min_child_samples': 44}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:29,529] Trial 40 finished with value: 1.0453684266519434 and parameters: {'lambda_l1': 3.5248645959387635e-08, 'lambda_l2': 4.969518723341312e-05, 'num_leaves': 239, 'feature_fraction': 0.9520449245672137, 'bagging_fraction': 0.9775309896110751, 'bagging_freq': 7, 'min_child_samples': 27}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:30,270] Trial 41 finished with value: 0.9316863094147454 and parameters: {'lambda_l1': 2.5913852949077933e-08, 'lambda_l2': 3.9340972439680574e-06, 'num_leaves': 226, 'feature_fraction': 0.796092109700937, 'bagging_fraction': 0.8292345354749124, 'bagging_freq': 3, 'min_child_samples': 17}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:30,889] Trial 42 finished with value: 0.9223625870868055 and parameters: {'lambda_l1': 2.427363191806899e-08, 'lambda_l2': 2.1191885978759972e-06, 'num_leaves': 226, 'feature_fraction': 0.8024588097781088, 'bagging_fraction': 0.8328435367843204, 'bagging_freq': 3, 'min_child_samples': 15}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:31,653] Trial 43 finished with value: 0.9613228202461916 and parameters: {'lambda_l1': 1.0288576694937133e-08, 'lambda_l2': 1.6846189354167715e-06, 'num_leaves': 244, 'feature_fraction': 0.8533240574204405, 'bagging_fraction': 0.8731711706800062, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:32,453] Trial 44 finished with value: 1.02918342047565 and parameters: {'lambda_l1': 5.9185161737931105e-08, 'lambda_l2': 1.6321014887416328e-07, 'num_leaves': 241, 'feature_fraction': 0.8924744112297922, 'bagging_fraction': 0.9178033190152914, 'bagging_freq': 4, 'min_child_samples': 23}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:33,314] Trial 45 finished with value: 0.9503073851812797 and parameters: {'lambda_l1': 6.35577412871665e-07, 'lambda_l2': 0.00021425542846810271, 'num_leaves': 223, 'feature_fraction': 0.8247717366436018, 'bagging_fraction': 0.9219864107440552, 'bagging_freq': 3, 'min_child_samples': 29}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:34,087] Trial 46 finished with value: 0.911400213365503 and parameters: {'lambda_l1': 2.5467234093568997e-06, 'lambda_l2': 1.1544489451652683e-05, 'num_leaves': 246, 'feature_fraction': 0.7207881247709023, 'bagging_fraction': 0.8243939692056141, 'bagging_freq': 4, 'min_child_samples': 15}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:34,854] Trial 47 finished with value: 0.9444991377600145 and parameters: {'lambda_l1': 3.885789374787994e-06, 'lambda_l2': 8.454004534028547e-06, 'num_leaves': 247, 'feature_fraction': 0.7187120658823272, 'bagging_fraction': 0.9673217604080264, 'bagging_freq': 5, 'min_child_samples': 9}. Best is trial 32 with value: 0.9090297446867125.
# [I 2025-03-08 23:45:35,637] Trial 48 finished with value: 0.8930619165826036 and parameters: {'lambda_l1': 3.3005727874884177e-07, 'lambda_l2': 1.9539508545659323e-05, 'num_leaves': 256, 'feature_fraction': 0.7724073368921065, 'bagging_fraction': 0.8863011993423009, 'bagging_freq': 4, 'min_child_samples': 8}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:35,991] Trial 49 finished with value: 1.1964351939385398 and parameters: {'lambda_l1': 3.3145569505838337e-07, 'lambda_l2': 0.00035940291514207517, 'num_leaves': 65, 'feature_fraction': 0.785341602914483, 'bagging_fraction': 0.821777363577784, 'bagging_freq': 4, 'min_child_samples': 25}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:36,745] Trial 50 finished with value: 1.1277854820137447 and parameters: {'lambda_l1': 1.67713264254574e-06, 'lambda_l2': 1.0330110445002879e-05, 'num_leaves': 180, 'feature_fraction': 0.7218905741337505, 'bagging_fraction': 0.7770922313124979, 'bagging_freq': 4, 'min_child_samples': 78}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:37,540] Trial 51 finished with value: 0.9616295995266584 and parameters: {'lambda_l1': 7.522376444764195e-08, 'lambda_l2': 6.77580684368268e-05, 'num_leaves': 256, 'feature_fraction': 0.7727928778872601, 'bagging_fraction': 0.9981027048259543, 'bagging_freq': 5, 'min_child_samples': 6}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:38,321] Trial 52 finished with value: 0.906605884886592 and parameters: {'lambda_l1': 2.2571138629021956e-06, 'lambda_l2': 5.0318727617689646e-05, 'num_leaves': 244, 'feature_fraction': 0.8267354438391502, 'bagging_fraction': 0.8925999045443233, 'bagging_freq': 6, 'min_child_samples': 15}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:39,101] Trial 53 finished with value: 0.9922793930638001 and parameters: {'lambda_l1': 3.3378129161099634e-06, 'lambda_l2': 2.0136348604869904e-05, 'num_leaves': 243, 'feature_fraction': 0.8591055591763521, 'bagging_fraction': 0.8915390483386063, 'bagging_freq': 6, 'min_child_samples': 15}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:39,837] Trial 54 finished with value: 0.9049993241162211 and parameters: {'lambda_l1': 2.9368246580825695e-05, 'lambda_l2': 6.438619515204862e-07, 'num_leaves': 233, 'feature_fraction': 0.745366077660209, 'bagging_fraction': 0.8588439130377881, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:40,496] Trial 55 finished with value: 0.959700452193115 and parameters: {'lambda_l1': 3.2047460810702517e-05, 'lambda_l2': 6.39025841998815e-08, 'num_leaves': 196, 'feature_fraction': 0.7341723099554693, 'bagging_fraction': 0.8628196034891862, 'bagging_freq': 5, 'min_child_samples': 10}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:41,225] Trial 56 finished with value: 0.9149376939313459 and parameters: {'lambda_l1': 7.447750407759515e-05, 'lambda_l2': 6.008125976387265e-07, 'num_leaves': 217, 'feature_fraction': 0.6949978356514588, 'bagging_fraction': 0.9293848977250126, 'bagging_freq': 4, 'min_child_samples': 17}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:42,114] Trial 57 finished with value: 1.0705173496021065 and parameters: {'lambda_l1': 1.0527800317134083e-05, 'lambda_l2': 6.874840866624218e-08, 'num_leaves': 205, 'feature_fraction': 0.764026819260028, 'bagging_fraction': 0.7372915552528269, 'bagging_freq': 4, 'min_child_samples': 53}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:42,843] Trial 58 finished with value: 1.0850192506625986 and parameters: {'lambda_l1': 1.8707989177354733e-06, 'lambda_l2': 2.820575085464315e-06, 'num_leaves': 230, 'feature_fraction': 0.7115761111175685, 'bagging_fraction': 0.46010096261306355, 'bagging_freq': 5, 'min_child_samples': 29}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:43,519] Trial 59 finished with value: 0.9319026898880866 and parameters: {'lambda_l1': 1.1643228218121762e-05, 'lambda_l2': 0.00028554329881911195, 'num_leaves': 244, 'feature_fraction': 0.6341148543557363, 'bagging_fraction': 0.9037950462265565, 'bagging_freq': 4, 'min_child_samples': 20}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:44,335] Trial 60 finished with value: 1.0014192954049148 and parameters: {'lambda_l1': 3.218100394857655e-07, 'lambda_l2': 5.772921793487311e-06, 'num_leaves': 246, 'feature_fraction': 0.6516826039159553, 'bagging_fraction': 0.6880387893675182, 'bagging_freq': 4, 'min_child_samples': 36}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:45,064] Trial 61 finished with value: 0.932533221724112 and parameters: {'lambda_l1': 8.691284220624777e-05, 'lambda_l2': 6.069461755645574e-07, 'num_leaves': 216, 'feature_fraction': 0.7397736893499861, 'bagging_fraction': 0.932912242477385, 'bagging_freq': 4, 'min_child_samples': 17}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:45,790] Trial 62 finished with value: 0.8956729959203324 and parameters: {'lambda_l1': 1.8775637374895554e-05, 'lambda_l2': 3.2255540092602855e-07, 'num_leaves': 232, 'feature_fraction': 0.685950147339384, 'bagging_fraction': 0.8433444698918905, 'bagging_freq': 5, 'min_child_samples': 9}. Best is trial 48 with value: 0.8930619165826036.
# [I 2025-03-08 23:45:46,550] Trial 63 finished with value: 0.8831178195602293 and parameters: {'lambda_l1': 4.20133238017457e-06, 'lambda_l2': 1.2438000701599315e-07, 'num_leaves': 247, 'feature_fraction': 0.6780719050869974, 'bagging_fraction': 0.8405732896721987, 'bagging_freq': 6, 'min_child_samples': 12}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:47,267] Trial 64 finished with value: 0.9096559356425853 and parameters: {'lambda_l1': 1.6902458504237255e-05, 'lambda_l2': 2.678887653873949e-07, 'num_leaves': 233, 'feature_fraction': 0.5947936676076114, 'bagging_fraction': 0.8404481226125641, 'bagging_freq': 6, 'min_child_samples': 8}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:47,974] Trial 65 finished with value: 0.8869080134851554 and parameters: {'lambda_l1': 2.254528784859096e-05, 'lambda_l2': 1.4051878502250768e-07, 'num_leaves': 230, 'feature_fraction': 0.5670274749070877, 'bagging_fraction': 0.7871781907015108, 'bagging_freq': 6, 'min_child_samples': 7}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:48,606] Trial 66 finished with value: 0.903657652050798 and parameters: {'lambda_l1': 5.489754675742006e-06, 'lambda_l2': 5.546530717808838e-08, 'num_leaves': 193, 'feature_fraction': 0.5298670329290374, 'bagging_fraction': 0.7837239064398909, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:49,218] Trial 67 finished with value: 0.9255377566558846 and parameters: {'lambda_l1': 2.9171467149187957e-05, 'lambda_l2': 3.3954616683441377e-08, 'num_leaves': 192, 'feature_fraction': 0.5303119170503245, 'bagging_fraction': 0.7860384290397477, 'bagging_freq': 6, 'min_child_samples': 7}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:49,822] Trial 68 finished with value: 0.9311823950430321 and parameters: {'lambda_l1': 4.298875426498734e-06, 'lambda_l2': 1.3704246689097285e-07, 'num_leaves': 203, 'feature_fraction': 0.44713632053492575, 'bagging_fraction': 0.8096453769613158, 'bagging_freq': 6, 'min_child_samples': 11}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:50,445] Trial 69 finished with value: 1.0703792651336452 and parameters: {'lambda_l1': 0.00016853490820396946, 'lambda_l2': 1.14260032633482e-08, 'num_leaves': 177, 'feature_fraction': 0.5139902604109452, 'bagging_fraction': 0.7270283749342279, 'bagging_freq': 6, 'min_child_samples': 24}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:50,872] Trial 70 finished with value: 1.0775603387351669 and parameters: {'lambda_l1': 6.09378091984146e-06, 'lambda_l2': 3.842099944458258e-08, 'num_leaves': 90, 'feature_fraction': 0.5677147826247037, 'bagging_fraction': 0.7742179985703507, 'bagging_freq': 5, 'min_child_samples': 8}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:51,678] Trial 71 finished with value: 0.8974913554395243 and parameters: {'lambda_l1': 1.112076433589928e-06, 'lambda_l2': 4.591784241461117e-07, 'num_leaves': 231, 'feature_fraction': 0.5293955981618101, 'bagging_fraction': 0.8522177641175976, 'bagging_freq': 6, 'min_child_samples': 13}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:52,199] Trial 72 finished with value: 0.9369583116236679 and parameters: {'lambda_l1': 1.2334196278999546e-06, 'lambda_l2': 3.975193420752495e-07, 'num_leaves': 212, 'feature_fraction': 0.48319858576510605, 'bagging_fraction': 0.8561118786780135, 'bagging_freq': 6, 'min_child_samples': 12}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:52,874] Trial 73 finished with value: 0.9531995208659413 and parameters: {'lambda_l1': 1.642296425508897e-05, 'lambda_l2': 1.414962035780367e-07, 'num_leaves': 229, 'feature_fraction': 0.5498026026274725, 'bagging_fraction': 0.7588118359499985, 'bagging_freq': 7, 'min_child_samples': 19}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:53,520] Trial 74 finished with value: 0.922299801293749 and parameters: {'lambda_l1': 5.581095535788416e-05, 'lambda_l2': 1.1609597622144888e-06, 'num_leaves': 219, 'feature_fraction': 0.4862809340929642, 'bagging_fraction': 0.7997924605298913, 'bagging_freq': 6, 'min_child_samples': 7}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:54,218] Trial 75 finished with value: 0.9167554160791362 and parameters: {'lambda_l1': 9.666127094863892e-07, 'lambda_l2': 6.44509156740705e-08, 'num_leaves': 235, 'feature_fraction': 0.5036800967227452, 'bagging_fraction': 0.863706195970635, 'bagging_freq': 7, 'min_child_samples': 14}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:54,731] Trial 76 finished with value: 0.9613922348152399 and parameters: {'lambda_l1': 7.587285579100528e-06, 'lambda_l2': 2.2043080426709424e-08, 'num_leaves': 143, 'feature_fraction': 0.5722218901129265, 'bagging_fraction': 0.8458320112301604, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:55,347] Trial 77 finished with value: 0.9303164963549345 and parameters: {'lambda_l1': 5.48972340977329e-06, 'lambda_l2': 4.091876597160648e-07, 'num_leaves': 209, 'feature_fraction': 0.4523520717561623, 'bagging_fraction': 0.81437671124765, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:55,973] Trial 78 finished with value: 1.5992835709636175 and parameters: {'lambda_l1': 3.769115907748339e-05, 'lambda_l2': 9.10295204363092e-08, 'num_leaves': 248, 'feature_fraction': 0.40256205480949264, 'bagging_fraction': 0.6649651387063532, 'bagging_freq': 6, 'min_child_samples': 96}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:56,426] Trial 79 finished with value: 1.0734177683048767 and parameters: {'lambda_l1': 0.00015272302674584424, 'lambda_l2': 2.539565028814621e-07, 'num_leaves': 122, 'feature_fraction': 0.5374478191067202, 'bagging_fraction': 0.906192792433546, 'bagging_freq': 5, 'min_child_samples': 21}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:57,163] Trial 80 finished with value: 0.9442686029329695 and parameters: {'lambda_l1': 3.7092336428026194e-07, 'lambda_l2': 1.1346836365539092e-06, 'num_leaves': 238, 'feature_fraction': 0.6148710671510117, 'bagging_fraction': 0.8328469513510546, 'bagging_freq': 6, 'min_child_samples': 16}. Best is trial 63 with value: 0.8831178195602293.
# [I 2025-03-08 23:45:57,932] Trial 81 finished with value: 0.8766808542159583 and parameters: {'lambda_l1': 1.9349564418828522e-06, 'lambda_l2': 0.0021425682042280725, 'num_leaves': 250, 'feature_fraction': 0.6908887803920055, 'bagging_fraction': 0.8771622936942292, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 81 with value: 0.8766808542159583.
# [I 2025-03-08 23:45:58,651] Trial 82 finished with value: 0.887679258923605 and parameters: {'lambda_l1': 2.509312822093074e-06, 'lambda_l2': 0.0015576661767866976, 'num_leaves': 228, 'feature_fraction': 0.6846453110079409, 'bagging_fraction': 0.8644559420780475, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 81 with value: 0.8766808542159583.
# [I 2025-03-08 23:45:59,378] Trial 83 finished with value: 0.8896682935267326 and parameters: {'lambda_l1': 1.220955042601408e-05, 'lambda_l2': 0.00739851843820486, 'num_leaves': 225, 'feature_fraction': 0.6737532927654664, 'bagging_fraction': 0.8012754307333292, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 81 with value: 0.8766808542159583.
# [I 2025-03-08 23:46:00,239] Trial 84 finished with value: 1.1259534548088304 and parameters: {'lambda_l1': 1.2847172071370354e-05, 'lambda_l2': 0.010062827164181231, 'num_leaves': 222, 'feature_fraction': 0.6785728075930617, 'bagging_fraction': 0.7867952079300502, 'bagging_freq': 7, 'min_child_samples': 73}. Best is trial 81 with value: 0.8766808542159583.
# [I 2025-03-08 23:46:00,987] Trial 85 finished with value: 0.8852913544168869 and parameters: {'lambda_l1': 1.1513694589370965e-06, 'lambda_l2': 0.02590729719171735, 'num_leaves': 250, 'feature_fraction': 0.6526850386891736, 'bagging_fraction': 0.8096878639026898, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 81 with value: 0.8766808542159583.
# [I 2025-03-08 23:46:01,807] Trial 86 finished with value: 0.9129657353516143 and parameters: {'lambda_l1': 1.0101276042270703e-06, 'lambda_l2': 0.001806552306273153, 'num_leaves': 228, 'feature_fraction': 0.6545161423540548, 'bagging_fraction': 0.8014883509567508, 'bagging_freq': 7, 'min_child_samples': 19}. Best is trial 81 with value: 0.8766808542159583.
# [I 2025-03-08 23:46:02,547] Trial 87 finished with value: 0.8670963493613207 and parameters: {'lambda_l1': 4.811762300574192e-07, 'lambda_l2': 0.0037677267137290697, 'num_leaves': 237, 'feature_fraction': 0.6804653707432552, 'bagging_fraction': 0.8399200640533226, 'bagging_freq': 7, 'min_child_samples': 13}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:03,317] Trial 88 finished with value: 0.9074787647148035 and parameters: {'lambda_l1': 3.9899082011223346e-07, 'lambda_l2': 0.005302734928268023, 'num_leaves': 252, 'feature_fraction': 0.7032507480536007, 'bagging_fraction': 0.8180580424689666, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:04,023] Trial 89 finished with value: 0.961157584496596 and parameters: {'lambda_l1': 6.8136529873478775, 'lambda_l2': 0.0014587327280778809, 'num_leaves': 250, 'feature_fraction': 0.6753636091997914, 'bagging_fraction': 0.8707143687082919, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:04,764] Trial 90 finished with value: 0.8807300145728505 and parameters: {'lambda_l1': 3.5885752565612185e-06, 'lambda_l2': 0.04650522815170589, 'num_leaves': 239, 'feature_fraction': 0.6893675638084572, 'bagging_fraction': 0.8368923183568929, 'bagging_freq': 7, 'min_child_samples': 13}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:05,559] Trial 91 finished with value: 0.8803238054125535 and parameters: {'lambda_l1': 3.20124037257314e-06, 'lambda_l2': 0.044470648314247296, 'num_leaves': 238, 'feature_fraction': 0.6870215962571993, 'bagging_fraction': 0.8388725834517902, 'bagging_freq': 7, 'min_child_samples': 13}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:06,281] Trial 92 finished with value: 0.9293775352777705 and parameters: {'lambda_l1': 2.447830344659606e-06, 'lambda_l2': 0.05414287856184301, 'num_leaves': 239, 'feature_fraction': 0.6173916413052679, 'bagging_fraction': 0.7643196466163318, 'bagging_freq': 7, 'min_child_samples': 13}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:07,055] Trial 93 finished with value: 0.9514372412018598 and parameters: {'lambda_l1': 5.981988501353492e-07, 'lambda_l2': 0.005273336047480068, 'num_leaves': 239, 'feature_fraction': 0.6597241446112909, 'bagging_fraction': 0.8334640698567689, 'bagging_freq': 7, 'min_child_samples': 23}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:07,826] Trial 94 finished with value: 0.9010100651524117 and parameters: {'lambda_l1': 1.5835477250435383e-06, 'lambda_l2': 0.026404595796227406, 'num_leaves': 250, 'feature_fraction': 0.6425996439813588, 'bagging_fraction': 0.8100848110162895, 'bagging_freq': 7, 'min_child_samples': 18}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:08,592] Trial 95 finished with value: 1.1333403565631952 and parameters: {'lambda_l1': 3.7957407544253797e-06, 'lambda_l2': 0.008377496378809546, 'num_leaves': 222, 'feature_fraction': 0.6917818156758209, 'bagging_fraction': 0.5652423984872186, 'bagging_freq': 7, 'min_child_samples': 43}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:09,336] Trial 96 finished with value: 0.8808888823719356 and parameters: {'lambda_l1': 2.3054113645625138e-07, 'lambda_l2': 0.14104031192929142, 'num_leaves': 250, 'feature_fraction': 0.5919834160113885, 'bagging_fraction': 0.8750592298752424, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:10,156] Trial 97 finished with value: 1.1589364566532558 and parameters: {'lambda_l1': 0.002133122178526256, 'lambda_l2': 0.11883671981622926, 'num_leaves': 241, 'feature_fraction': 0.5787677456461936, 'bagging_fraction': 0.7449775030515932, 'bagging_freq': 7, 'min_child_samples': 61}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:10,919] Trial 98 finished with value: 0.9421143812137474 and parameters: {'lambda_l1': 1.0256968456566147e-07, 'lambda_l2': 0.015369581597279993, 'num_leaves': 249, 'feature_fraction': 0.5966811518665512, 'bagging_fraction': 0.874984976452844, 'bagging_freq': 7, 'min_child_samples': 16}. Best is trial 87 with value: 0.8670963493613207.
# [I 2025-03-08 23:46:11,689] Trial 99 finished with value: 0.9924386703795727 and parameters: {'lambda_l1': 2.3355662891169362e-07, 'lambda_l2': 0.04799757636318216, 'num_leaves': 215, 'feature_fraction': 0.6294010159402768, 'bagging_fraction': 0.7062630692743758, 'bagging_freq': 7, 'min_child_samples': 13}. Best is trial 87 with value: 0.8670963493613207.
# LightGBM RMSE: 0.8670963493613207

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/anaconda3/lib/python3.12/site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/anaconda3/lib/python3.12/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 3.0 MB/s eta 0:00:0000:0100:01
# Downloading alembic-1.15.1-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.9 alembic-1.15.1 colorlog-6.9.0 optuna-4.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import RandomForestRegressor

estimators = [
    ("lgb", lgb.LGBMRegressor(**lgb_params)),
    ("rf", RandomForestRegressor(max_depth=32, random_state=1)),
]

stacker = StackingRegressor(
    estimators=estimators, final_estimator=RandomForestRegressor()
)
stacker.fit(X_train, y_train)

stacker_pred = stacker.predict(X_test)

stacker_rmse = np.sqrt(mean_squared_error(y_test, stacker_pred))

print(f"Stacker RMSE: {stacker_rmse}\n")
